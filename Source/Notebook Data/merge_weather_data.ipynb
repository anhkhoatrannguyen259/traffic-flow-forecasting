# %%
import pandas as pd

# %% [markdown]
# - Import data

# %%
# Import traffic data 
traffic_data = pd.read_csv("/content/drive/MyDrive/Courses/Khoá luận tốt nghiệp/Dataset/data_p3.csv")

# Import weather data
weather_data = pd.read_excel("/content/drive/MyDrive/Courses/Khoá luận tốt nghiệp/Dataset/weather_data/cork_weather_data.xlsx", sheet_name=1)

# %%
traffic_data
# Out:
#                    id            datetime            location  value
# 0       000000001271A 2021-01-01 00:00:00  51.86242, -8.47908     17
# 1       000000001271A 2021-01-01 01:00:00  51.86242, -8.47908      7
# 2       000000001271A 2021-01-01 02:00:00  51.86242, -8.47908      8
# 3       000000001271A 2021-01-01 03:00:00  51.86242, -8.47908      8
# 4       000000001271A 2021-01-01 04:00:00  51.86242, -8.47908      5
# ...               ...                 ...                 ...    ...
# 192715  000000001256B 2021-12-31 19:00:00  51.88825, -8.39061    768
# 192716  000000001256B 2021-12-31 20:00:00  51.88825, -8.39061    531
# 192717  000000001256B 2021-12-31 21:00:00  51.88825, -8.39061    277
# 192718  000000001256B 2021-12-31 22:00:00  51.88825, -8.39061    212
# 192719  000000001256B 2021-12-31 23:00:00  51.88825, -8.39061    146
#
# [192720 rows x 4 columns]

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192720 entries, 0 to 192719
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        192720 non-null  object
#  1   datetime  192720 non-null  object
#  2   location  192720 non-null  object
#  3   value     192720 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 5.9+ MB

# %%
traffic_data['datetime'] = traffic_data['datetime'].astype('datetime64')

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192720 entries, 0 to 192719
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        192720 non-null  object
#  1   datetime  192720 non-null  datetime64[ns]
#  2   location  192720 non-null  object
#  3   value     192720 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 5.9+ MB

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    8760 non-null   datetime64[ns]
#  1   ind     8760 non-null   int64
#  2   rain    8760 non-null   float64
#  3   ind.1   8760 non-null   int64
#  4   temp    8760 non-null   float64
#  5   ind.2   8760 non-null   int64
#  6   wetb    8760 non-null   float64
#  7   dewpt   8760 non-null   float64
#  8   vappr   8760 non-null   float64
#  9   rhum    8760 non-null   int64
#  10  msl     8760 non-null   float64
#  11  ind.3   8760 non-null   int64
#  12  wdsp    8760 non-null   int64
#  13  ind.4   8760 non-null   int64
#  14  wddir   8760 non-null   int64
#  15  ww      8760 non-null   int64
#  16  w       8760 non-null   int64
#  17  sun     8760 non-null   float64
#  18  vis     8760 non-null   int64
#  19  clht    8760 non-null   int64
#  20  clamt   8760 non-null   int64
# ...

# %% [markdown]
# - Test small-scale data

# %%
data_A = traffic_data.iloc[22:27,:]
data_A
# Out:
#                id            datetime            location  value
# 22  000000001271A 2021-01-01 22:00:00  51.86242, -8.47908     23
# 23  000000001271A 2021-01-01 23:00:00  51.86242, -8.47908     12
# 24  000000001271A 2021-01-02 00:00:00  51.86242, -8.47908     10
# 25  000000001271A 2021-01-02 01:00:00  51.86242, -8.47908      4
# 26  000000001271A 2021-01-02 02:00:00  51.86242, -8.47908      1

# %%
data_B = weather_data.iloc[22:27,:]
data_B
# Out:
#                   date  ind  rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 22 2021-01-01 22:00:00    0   0.0      0   2.5      0   1.9    1.0    6.5
# 23 2021-01-01 23:00:00    3   0.0      0   1.7      0   1.4    0.8    6.5
# 24 2021-01-02 00:00:00    3   0.0      0   0.9      0   0.6    0.2    6.1
# 25 2021-01-02 01:00:00    3   0.0      0   0.7      0   0.3   -0.3    5.9
# 26 2021-01-02 02:00:00    3   0.0      0   0.1      1  -0.2   -0.7    5.8
#
#     rhum  ...  ind.3  wdsp  ind.4  wddir  ww   w  sun    vis  clht  clamt
# 22    89  ...      2     8      2    340   2  11  0.0  20000    28      5
# 23    94  ...      2     6      2    320   2  11  0.0  20000    28      6
# 24    94  ...      2     9      2    320   2  11  0.0  20000   999      2
# 25    92  ...      2     9      2    340   2  11  0.0  20000   999      1
# 26    94  ...      2     8      2    320   2  11  0.0  20000   999      1
#
# [5 rows x 21 columns]

# %%
df_test = pd.merge(data_A, data_B, left_on='datetime', right_on='date')
df_test
# Out:
#               id            datetime            location  value  \
# 0  000000001271A 2021-01-01 22:00:00  51.86242, -8.47908     23
# 1  000000001271A 2021-01-01 23:00:00  51.86242, -8.47908     12
# 2  000000001271A 2021-01-02 00:00:00  51.86242, -8.47908     10
# 3  000000001271A 2021-01-02 01:00:00  51.86242, -8.47908      4
# 4  000000001271A 2021-01-02 02:00:00  51.86242, -8.47908      1
#
#                  date  ind  rain  ind.1  temp  ind.2  ...  ind.3  wdsp  ind.4  \
# 0 2021-01-01 22:00:00    0   0.0      0   2.5      0  ...      2     8      2
# 1 2021-01-01 23:00:00    3   0.0      0   1.7      0  ...      2     6      2
# 2 2021-01-02 00:00:00    3   0.0      0   0.9      0  ...      2     9      2
# 3 2021-01-02 01:00:00    3   0.0      0   0.7      0  ...      2     9      2
# 4 2021-01-02 02:00:00    3   0.0      0   0.1      1  ...      2     8      2
#
#    wddir  ww   w  sun    vis  clht  clamt
# 0    340   2  11  0.0  20000    28      5
# ...

# %% [markdown]
# - Merge full data

# %%
df = pd.merge(traffic_data, weather_data, left_on='datetime', right_on='date').drop('date',axis=1).rename(columns = {'ind':'irain', 'ind.1':'itemp', 'ind.2':'iwb', 'ind.3':'iwdsp', 'ind.4':'iwddir'})
df
# Out:
#                    id            datetime            location  value  irain  \
# 0       000000001271A 2021-01-01 00:00:00  51.86242, -8.47908     17      0
# 1       000000001271B 2021-01-01 00:00:00  51.86242, -8.47908     10      0
# 2       000000001403A 2021-01-01 00:00:00  51.87619, -8.49964    125      0
# 3       000000001403B 2021-01-01 00:00:00  51.87619, -8.49964    111      0
# 4       000000001404A 2021-01-01 00:00:00  51.87567, -8.51047     86      0
# ...               ...                 ...                 ...    ...    ...
# 192715  000000001283B 2021-12-31 23:00:00  51.87578, -8.41266    117      0
# 192716  000000001258A 2021-12-31 23:00:00   51.88229, -8.4076    126      0
# 192717  000000001258B 2021-12-31 23:00:00   51.88229, -8.4076    144      0
# 192718  000000001256A 2021-12-31 23:00:00  51.88825, -8.39061    127      0
# 192719  000000001256B 2021-12-31 23:00:00  51.88825, -8.39061    146      0
#
# ...

# %%
# Export dataset
df.to_csv("/content/drive/MyDrive/Courses/Khoá luận tốt nghiệp/Dataset/final_data_2.csv", index=False)
