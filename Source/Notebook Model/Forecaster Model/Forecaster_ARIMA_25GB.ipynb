# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install latest pre-release version of bigdl-chronos 
# Installing bigdl-chronos from pip will automatically install pyspark, bigdl, and their dependencies.
#!pip install --pre --upgrade bigdl-chronos[all]
# !pip install bigdl-chronos[all]==2.0.0
# !pip install torchmetrics==0.7.3
# !pip uninstall -y torchtext
#!pip install tensorflow-gpu==1.15.0
# !pip install pmdarima
exit() # restart the runtime to refresh installed pkg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bigdl-chronos[all]==2.0.0
#   Downloading bigdl_chronos-2.0.0-py3-none-manylinux1_x86_64.whl (222 kB)
#      |████████████████████████████████| 222 kB 5.2 MB/s
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from bigdl-chronos[all]==2.0.0) (0.10.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from bigdl-chronos[all]==2.0.0) (1.0.2)
# Collecting bigdl-orca==2.0.0
#   Downloading bigdl_orca-2.0.0-py3-none-manylinux1_x86_64.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 1.3 MB/s
# Collecting bigdl-nano[pytorch]
#   Downloading bigdl_nano-2.0.0-py3-none-manylinux2010_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 37.3 MB/s
# Collecting pandas<1.3.0,>=1.0.5
#   Downloading pandas-1.2.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 24.0 MB/s
# Collecting bigdl-dllib==2.0.0
#   Downloading bigdl_dllib-2.0.0-py3-none-manylinux1_x86_64.whl (101.0 MB)
#      |████████████████████████████████| 101.0 MB 33 kB/s
# Collecting conda-pack==0.3.1
#   Downloading conda_pack-0.3.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.7.0)
# Collecting bigdl-math==2.0.0
#   Downloading bigdl_math-2.0.0-py3-none-manylinux2010_x86_64.whl (35.4 MB)
#      |████████████████████████████████| 35.4 MB 1.3 MB/s
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (23.0.0)
# Collecting bigdl-tf==2.0.0
#   Downloading bigdl_tf-2.0.0-py3-none-manylinux2010_x86_64.whl (71.0 MB)
#      |████████████████████████████████| 71.0 MB 179 kB/s
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.7/dist-packages (from bigdl-dllib==2.0.0->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.21.6)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from bigdl-dllib==2.0.0->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.15.0)
# Collecting pyspark==2.4.6
#   Downloading pyspark-2.4.6.tar.gz (218.4 MB)
#      |████████████████████████████████| 218.4 MB 48 kB/s
# Collecting aiohttp==3.8.1
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 42.9 MB/s
# Collecting ray[default]==1.9.2
#   Downloading ray-1.9.2-cp37-cp37m-manylinux2014_x86_64.whl (57.6 MB)
#      |████████████████████████████████| 57.6 MB 109 kB/s
# Collecting aioredis==1.3.1
#   Downloading aioredis-1.3.1-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.6 MB/s
# Collecting async-timeout==4.0.1
#   Downloading async_timeout-4.0.1-py3-none-any.whl (5.7 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (5.4.8)
# Collecting hiredis==2.0.0
#   Downloading hiredis-2.0.0-cp37-cp37m-manylinux2010_x86_64.whl (85 kB)
#      |████████████████████████████████| 85 kB 3.9 MB/s
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (2.8.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (4.2.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 61.6 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (21.4.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.9 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 64.0 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (2.0.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from conda-pack==0.3.1->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (57.4.0)
# Collecting py4j==0.10.7
#   Downloading py4j-0.10.7-py2.py3-none-any.whl (197 kB)
#      |████████████████████████████████| 197 kB 60.6 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.13)
# Requirement already satisfied: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.17.3)
# Collecting redis>=3.5.0
#   Downloading redis-4.3.1-py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 54.7 MB/s
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.0.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (7.1.2)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.46.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (4.3.3)
# Collecting colorful
#   Downloading colorful-0.5.4-py2.py3-none-any.whl (201 kB)
#      |████████████████████████████████| 201 kB 61.6 MB/s
# Requirement already satisfied: smart-open in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (6.0.0)
# Collecting opencensus
#   Downloading opencensus-0.9.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 59.6 MB/s
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (2.23.0)
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.12-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 30.9 MB/s
# Collecting gpustat>=1.0.0b1
#   Downloading gpustat-1.0.0b1.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 276 kB/s
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.8.9)
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 53.2 MB/s
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat>=1.0.0b1->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (7.352.0)
# Collecting blessed>=1.17.1
#   Downloading blessed-1.19.1-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.2 MB/s
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.7/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.2.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.3.0,>=1.0.5->bigdl-chronos[all]==2.0.0) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.3.0,>=1.0.5->bigdl-chronos[all]==2.0.0) (2.8.2)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (4.11.3)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting redis>=3.5.0
#   Downloading redis-4.3.0-py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 58.5 MB/s
#   Downloading redis-4.2.2-py3-none-any.whl (226 kB)
#      |████████████████████████████████| 226 kB 58.4 MB/s
#   Downloading redis-4.2.1-py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 62.8 MB/s
#   Downloading redis-4.2.0-py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 37.0 MB/s
#   Downloading redis-4.1.4-py3-none-any.whl (175 kB)
#      |████████████████████████████████| 175 kB 56.1 MB/s
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.0->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.14.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.0->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.0.9)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp==3.8.1->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (2.10)
# Requirement already satisfied: intel-openmp in /usr/local/lib/python3.7/dist-packages (from bigdl-nano[pytorch]->bigdl-chronos[all]==2.0.0) (2022.1.0)
# Collecting pytorch-lightning==1.4.2
#   Downloading pytorch_lightning-1.4.2-py3-none-any.whl (916 kB)
#      |████████████████████████████████| 916 kB 60.0 MB/s
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.8 MB)
#      |████████████████████████████████| 47.8 MB 45.7 MB/s
# Collecting PyTurboJPEG
#   Downloading PyTurboJPEG-1.6.6.tar.gz (11 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.11.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      |████████████████████████████████| 5.2 MB 38.2 MB/s
# Collecting opencv-transforms
#   Downloading opencv_transforms-0.0.6-py3-none-any.whl (18 kB)
# Collecting onnx
#   Downloading onnx-1.11.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 31.6 MB/s
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 2.5 kB/s
# Collecting torchvision==0.10.0
#   Downloading torchvision-0.10.0-cp37-cp37m-manylinux1_x86_64.whl (22.1 MB)
#      |████████████████████████████████| 22.1 MB 42.8 MB/s
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 52.6 MB/s
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.4.2->bigdl-nano[pytorch]->bigdl-chronos[all]==2.0.0) (4.64.0)
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 56.2 MB/s
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 59.5 MB/s
# Collecting torchmetrics>=0.4.0
#   Downloading torchmetrics-0.8.2-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 53.5 MB/s
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.10.0->bigdl-nano[pytorch]->bigdl-chronos[all]==2.0.0) (7.1.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.0.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.3.7)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (5.7.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime->bigdl-nano[pytorch]->bigdl-chronos[all]==2.0.0) (2.0)
# Collecting opencensus-context>=0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.31.5)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.56.1)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->bigdl-chronos[all]==2.0.0) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->bigdl-chronos[all]==2.0.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->bigdl-chronos[all]==2.0.0) (3.1.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->bigdl-chronos[all]==2.0.0) (0.5.2)
# Building wheels for collected packages: pyspark, gpustat, future, PyTurboJPEG
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-2.4.6-py2.py3-none-any.whl size=218814407 sha256=85ab94f848f9b24b89675663c4dd5bd269cf1e12e62fa5e7dcd625d6b01c50f1
#   Stored in directory: /root/.cache/pip/wheels/f1/42/b0/ba397759613f4feb1611021a2503e60e344e546671b2ae04f8
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-1.0.0b1-py3-none-any.whl size=15979 sha256=35c17e1248189160e604c88509aa06424ad4b8f133c2678f623d791ef72b9dba
#   Stored in directory: /root/.cache/pip/wheels/1a/16/e2/3e2437fba4c4b6a97a97bd96fce5d14e66cff5c4966fb1cc8c
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=0ca8542032315de1c5ee584edc698b0b126e2f4fe018f636f9f8834475899916
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for PyTurboJPEG (setup.py) ... done
#   Created wheel for PyTurboJPEG: filename=PyTurboJPEG-1.6.6-py3-none-any.whl size=12169 sha256=d4317e8479cadae7c16b7ccb27b1e8a6456a10aec1262d3d72f05d39826cf33a
#   Stored in directory: /root/.cache/pip/wheels/d4/ad/ad/eae0f574bbf7271d34d605ee01338bd4f2c132de91bff0f12f
# Successfully built pyspark gpustat future PyTurboJPEG
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, torch, pyDeprecate, py4j, fsspec, deprecated, aiohttp, torchmetrics, redis, pyyaml, pyspark, opencensus-context, hiredis, future, blessed, torchvision, tensorboardX, ray, PyTurboJPEG, pytorch-lightning, py-spy, pandas, opencv-transforms, opencv-python-headless, opencensus, onnxruntime, onnx, gpustat, conda-pack, colorful, bigdl-tf, bigdl-nano, bigdl-math, bigdl-dllib, aioredis, aiohttp-cors, setproctitle, bigdl-orca, bigdl-chronos
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.12.0+cu113
#     Uninstalling torchvision-0.12.0+cu113:
#       Successfully uninstalled torchvision-0.12.0+cu113
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.9.0 which is incompatible.
# Successfully installed PyTurboJPEG-1.6.6 aiohttp-3.8.1 aiohttp-cors-0.7.0 aioredis-1.3.1 aiosignal-1.2.0 async-timeout-4.0.1 asynctest-0.13.0 bigdl-chronos-2.0.0 bigdl-dllib-2.0.0 bigdl-math-2.0.0 bigdl-nano-2.0.0 bigdl-orca-2.0.0 bigdl-tf-2.0.0 blessed-1.19.1 colorful-0.5.4 conda-pack-0.3.1 deprecated-1.2.13 frozenlist-1.3.0 fsspec-2022.5.0 future-0.18.2 gpustat-1.0.0b1 hiredis-2.0.0 multidict-6.0.2 onnx-1.11.0 onnxruntime-1.11.1 opencensus-0.9.0 opencensus-context-0.1.2 opencv-python-headless-4.5.5.64 opencv-transforms-0.0.6 pandas-1.2.5 py-spy-0.3.12 py4j-0.10.7 pyDeprecate-0.3.1 pyspark-2.4.6 pytorch-lightning-1.4.2 pyyaml-6.0 ray-1.9.2 redis-4.1.4 setproctitle-1.2.3 tensorboardX-2.5 torch-1.9.0 torchmetrics-0.8.2 torchvision-0.10.0 yarl-1.7.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics==0.7.3
#   Downloading torchmetrics-0.7.3-py3-none-any.whl (398 kB)
#      |████████████████████████████████| 398 kB 4.8 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.7.3) (21.3)
# Requirement already satisfied: pyDeprecate==0.3.* in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.7.3) (0.3.1)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.7.3) (1.9.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.7.3) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics==0.7.3) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics==0.7.3) (3.0.9)
# Installing collected packages: torchmetrics
#   Attempting uninstall: torchmetrics
#     Found existing installation: torchmetrics 0.8.2
#     Uninstalling torchmetrics-0.8.2:
#       Successfully uninstalled torchmetrics-0.8.2
# Successfully installed torchmetrics-0.7.3
# Found existing installation: torchtext 0.12.0
# Uninstalling torchtext-0.12.0:
#   Successfully uninstalled torchtext-0.12.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pmdarima
#   Downloading pmdarima-1.8.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.3 MB/s
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.2.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading statsmodels-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 40.9 MB/s
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.30)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.9)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.5 statsmodels-0.13.2

# %% [markdown]
# ## **Đánh giá theo độ dài dữ liệu**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("/content/drive/MyDrive/Courses/Khoá luận tốt nghiệp/Dataset/final_data_6.csv")

df['datetime'] = df['datetime'].astype('datetime64')
df

#------------>>> IMPORT NECESARY LIBRARIES AND MODULES
from bigdl.orca import init_orca_context, stop_orca_context
from bigdl.orca import OrcaContext
from bigdl.chronos.data import TSDataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import bigdl.orca.automl.hp as hp
from bigdl.chronos.forecaster.arima_forecaster import ARIMAForecaster
from bigdl.orca.automl.metrics import Evaluator

#------------>>> RECOMMENDED TO SET IT TO TRUE WHEN RUNNING BIGDL-CHRONOS IN JUPYTER NOTEBOOK 
OrcaContext.log_output = True # (this will display terminal's stdout and stderr in the Jupyter notebook).

init_orca_context(cluster_mode="local", cores=4, init_ray_on_spark=True) # run in local mode



#------------>>> LOOP FOR FEATURES

tsdata_train, tsdata_val, tsdata_test = TSDataset.from_pandas(df, dt_col="datetime", id_col="id", target_col="value", with_split=True, val_ratio=0.1, test_ratio=0.1)

# minmax_scaler = MinMaxScaler()

# for tsdata in [tsdata_train, tsdata_val, tsdata_test]:
#   tsdata.scale(minmax_scaler, fit=(tsdata is tsdata_train))

# X_train, y_train = tsdata_train.to_numpy()
# X_val, y_val = tsdata_val.to_numpy()
# X_test, y_test = tsdata_test.to_numpy()
# X_train.shape, y_train.shape, X_test.shape, y_test.shape

train_data = tsdata_train.to_pandas()
validation_data = tsdata_val.to_pandas()
test_data = tsdata_test.to_pandas()

print(train_data.shape[0])
print(validation_data.shape[0])

# BUILD MODEL
forecaster = ARIMAForecaster(p=2, q=2, seasonality_mode=True)
forecaster.fit(train_data['value'].to_numpy(), test_data['value'].to_numpy())

# EVALUATE
forecaster.evaluate(test_data['value'].to_numpy(), metrics=['rmse', 'mae'])
# Out:
# /usr/local/lib/python3.7/dist-packages/bigdl/chronos/forecaster/__init__.py:36: UserWarning: Please install `tensorflow<2.0.0` to use MTNetForecaster.
#   warnings.warn("Please install `tensorflow<2.0.0` to use MTNetForecaster.")
# /usr/local/lib/python3.7/dist-packages/bigdl/chronos/forecaster/__init__.py:41: UserWarning: Please install `prophet` to use ProphetForecaster.
#   warnings.warn("Please install `prophet` to use ProphetForecaster.")
# Initializing orca context
# Current pyspark location is : /usr/local/lib/python3.7/dist-packages/pyspark/__init__.py
# Start to getOrCreate SparkContext
# pyspark_submit_args is:  --driver-class-path /usr/local/lib/python3.7/dist-packages/bigdl/share/dllib/lib/bigdl-dllib-spark_2.4.6-2.0.0-jar-with-dependencies.jar:/usr/local/lib/python3.7/dist-packages/bigdl/share/orca/lib/bigdl-orca-spark_2.4.6-2.0.0-jar-with-dependencies.jar pyspark-shell
# 2022-05-26 13:10:32 WARN  NativeCodeLoader:62 - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/lib/python3.7/dist-packages/pyspark/jars/spark-unsafe_2.11-2.4.6.jar) to method java.nio.Bits.unaligned()
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2022-05-26 13:10:36,278 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 2022-05-26 13:10:36,284 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 2022-05-26 13:10:36,287 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 2022-05-26 13:10:36,289 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 22-05-26 13:10:36 [Thread-3] INFO  Engine$:121 - Auto detect executor number and executor cores number
# 22-05-26 13:10:36 [Thread-3] INFO  Engine$:123 - Executor number is 1 and executor cores number is 4
# User settings:
#
#    KMP_AFFINITY=granularity=fine,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    OMP_NUM_THREADS=1
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_HAND_THREAD=false
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_FORKJOIN_FRAMES=true
#    KMP_FORKJOIN_FRAMES_MODE=3
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_ITT_PREPARE_DELAY=0
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_MWAIT_HINTS=0
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USER_LEVEL_MWAIT=false
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=true
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEBUG=disabled
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=2147483647
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED=false
#    OMP_NUM_THREADS='1'
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_TOOL=enabled
#    OMP_TOOL_LIBRARIES: value is not defined
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='noverbose,warnings,respect,granularity=fine,compact,1,0'
# 22-05-26 13:10:37 [Thread-3] INFO  ThreadPool$:95 - Set mkl threads to 1 on thread 17
# 2022-05-26 13:10:37 WARN  SparkContext:66 - Using an existing SparkContext; some configuration may not take effect.
# 22-05-26 13:10:37 [Thread-3] INFO  Engine$:446 - Find existing spark context. Checking the spark conf...
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.Sample
# BigDLBasePickler registering: bigdl.dllib.utils.common  Sample
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.EvaluatedResult
# BigDLBasePickler registering: bigdl.dllib.utils.common  EvaluatedResultSuccessfully got a SparkContext
#
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.JTensor
# BigDLBasePickler registering: bigdl.dllib.utils.common  JTensor
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.JActivity
# BigDLBasePickler registering: bigdl.dllib.utils.common  JActivity
# 2022-05-26 13:10:41,285	INFO services.py:1340 -- View the Ray dashboard at http://172.28.0.2:8265
# {'node_ip_address': '172.28.0.2', 'raylet_ip_address': '172.28.0.2', 'redis_address': '172.28.0.2:6379', 'object_store_address': '/tmp/ray/session_2022-05-26_13-10-37_662979_70/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-05-26_13-10-37_662979_70/sockets/raylet', 'webui_url': '172.28.0.2:8265', 'session_dir': '/tmp/ray/session_2022-05-26_13-10-37_662979_70', 'metrics_export_port': 58469, 'node_id': 'aa1f7a7ef8fb23c92eb1f9585b2d4c9aaabc17328573a569bb2cf450'}
# 154176
# 19272
# 2022-05-26 13:11:53,920	WARNING worker.py:1245 -- (ip=172.28.0.2) The agent on node 8a66d3b37839 failed to be restarted 5 times. There are 3 possible problems if you see this error.
#   1. The dashboard might not display correct information on this node.
#   2. Metrics on this node won't be reported.
#   3. runtime_env APIs won't work.
# Check out the `dashboard_agent.log` to see the detailed failure messages.
# [array(1303.2506963), array(903.35365659)]

# %% [markdown]
# ## **Run Model**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install latest pre-release version of bigdl-chronos 
# Installing bigdl-chronos from pip will automatically install pyspark, bigdl, and their dependencies.
#!pip install --pre --upgrade bigdl-chronos[all]
# !pip install bigdl-chronos[all]==2.0.0
# !pip install torchmetrics==0.7.3
# !pip uninstall -y torchtext
#!pip install tensorflow-gpu==1.15.0
# !pip install pmdarima
exit() # restart the runtime to refresh installed pkg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bigdl-chronos[all]==2.0.0
#   Downloading bigdl_chronos-2.0.0-py3-none-manylinux1_x86_64.whl (222 kB)
#      |████████████████████████████████| 222 kB 5.2 MB/s
# Collecting bigdl-orca==2.0.0
#   Downloading bigdl_orca-2.0.0-py3-none-manylinux1_x86_64.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 1.2 MB/s
# Collecting bigdl-nano[pytorch]
#   Downloading bigdl_nano-2.0.0-py3-none-manylinux2010_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 37.6 MB/s
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from bigdl-chronos[all]==2.0.0) (0.10.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from bigdl-chronos[all]==2.0.0) (1.0.2)
# Collecting pandas<1.3.0,>=1.0.5
#   Downloading pandas-1.2.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 40.0 MB/s
# Collecting bigdl-math==2.0.0
#   Downloading bigdl_math-2.0.0-py3-none-manylinux2010_x86_64.whl (35.4 MB)
#      |████████████████████████████████| 35.4 MB 1.2 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.7.1)
# Collecting bigdl-tf==2.0.0
#   Downloading bigdl_tf-2.0.0-py3-none-manylinux2010_x86_64.whl (71.0 MB)
#      |████████████████████████████████| 71.0 MB 1.1 MB/s
# Collecting bigdl-dllib==2.0.0
#   Downloading bigdl_dllib-2.0.0-py3-none-manylinux1_x86_64.whl (101.0 MB)
#      |████████████████████████████████| 101.0 MB 1.2 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (21.3)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (23.1.0)
# Collecting conda-pack==0.3.1
#   Downloading conda_pack-0.3.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.7/dist-packages (from bigdl-dllib==2.0.0->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.21.6)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from bigdl-dllib==2.0.0->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.15.0)
# Collecting pyspark==2.4.6
#   Downloading pyspark-2.4.6.tar.gz (218.4 MB)
#      |████████████████████████████████| 218.4 MB 45 kB/s
# Collecting hiredis==2.0.0
#   Downloading hiredis-2.0.0-cp37-cp37m-manylinux2010_x86_64.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.0 MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (5.4.8)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (2.8.0)
# Collecting ray[tune]==1.9.2
#   Downloading ray-1.9.2-cp37-cp37m-manylinux2014_x86_64.whl (57.6 MB)
#      |████████████████████████████████| 57.6 MB 185 kB/s
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting aiohttp==3.8.1
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 43.2 MB/s
# Collecting async-timeout==4.0.1
#   Downloading async_timeout-4.0.1-py3-none-any.whl (5.7 kB)
# Collecting aioredis==1.3.1
#   Downloading aioredis-1.3.1-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.6 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 70.4 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 71.4 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (4.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (21.4.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.4 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from conda-pack==0.3.1->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (57.4.0)
# Collecting py4j==0.10.7
#   Downloading py4j-0.10.7-py2.py3-none-any.whl (197 kB)
#      |████████████████████████████████| 197 kB 70.7 MB/s
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (4.3.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.0.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.13)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.46.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (7.1.2)
# Requirement already satisfied: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.17.3)
# Collecting redis>=3.5.0
#   Downloading redis-4.3.3-py3-none-any.whl (244 kB)
#      |████████████████████████████████| 244 kB 64.3 MB/s
# Requirement already satisfied: smart-open in /usr/local/lib/python3.7/dist-packages (from ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (6.0.0)
# Collecting gpustat>=1.0.0b1
#   Downloading gpustat-1.0.0b1.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 220 kB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (2.23.0)
# Collecting opencensus
#   Downloading opencensus-0.9.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 54.3 MB/s
# Collecting colorful
#   Downloading colorful-0.5.4-py2.py3-none-any.whl (201 kB)
#      |████████████████████████████████| 201 kB 66.7 MB/s
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.12-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 47.5 MB/s
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.14.1)
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 64.1 MB/s
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.8.9)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat>=1.0.0b1->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (7.352.0)
# Collecting blessed>=1.17.1
#   Downloading blessed-1.19.1-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.1 MB/s
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.7/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.2.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.3.0,>=1.0.5->bigdl-chronos[all]==2.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.3.0,>=1.0.5->bigdl-chronos[all]==2.0.0) (2022.1)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting redis>=3.5.0
#   Downloading redis-4.3.2-py3-none-any.whl (244 kB)
#      |████████████████████████████████| 244 kB 57.2 MB/s
#   Downloading redis-4.3.1-py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 64.8 MB/s
#   Downloading redis-4.3.0-py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 65.2 MB/s
#   Downloading redis-4.2.2-py3-none-any.whl (226 kB)
#      |████████████████████████████████| 226 kB 70.1 MB/s
#   Downloading redis-4.2.1-py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 54.7 MB/s
#   Downloading redis-4.2.0-py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 44.4 MB/s
#   Downloading redis-4.1.4-py3-none-any.whl (175 kB)
#      |████████████████████████████████| 175 kB 50.2 MB/s
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (4.11.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.0->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.14.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.0->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.0.9)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp==3.8.1->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (2.10)
# Requirement already satisfied: intel-openmp in /usr/local/lib/python3.7/dist-packages (from bigdl-nano[pytorch]->bigdl-chronos[all]==2.0.0) (2022.1.0)
# Collecting onnx
#   Downloading onnx-1.11.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 37.4 MB/s
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 2.3 kB/s
# Collecting pytorch-lightning==1.4.2
#   Downloading pytorch_lightning-1.4.2-py3-none-any.whl (916 kB)
#      |████████████████████████████████| 916 kB 55.3 MB/s
# Collecting onnxruntime
#   Downloading onnxruntime-1.11.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      |████████████████████████████████| 5.2 MB 53.4 MB/s
# Collecting opencv-transforms
#   Downloading opencv_transforms-0.0.6-py3-none-any.whl (18 kB)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (48.3 MB)
#      |████████████████████████████████| 48.3 MB 1.2 MB/s
# Collecting torchvision==0.10.0
#   Downloading torchvision-0.10.0-cp37-cp37m-manylinux1_x86_64.whl (22.1 MB)
#      |████████████████████████████████| 22.1 MB 1.2 MB/s
# Collecting PyTurboJPEG
#   Downloading PyTurboJPEG-1.6.6.tar.gz (11 kB)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.4.2->bigdl-nano[pytorch]->bigdl-chronos[all]==2.0.0) (4.64.0)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 57.5 MB/s
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 51.6 MB/s
# Collecting torchmetrics>=0.4.0
#   Downloading torchmetrics-0.9.1-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 57.4 MB/s
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 54.6 MB/s
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.10.0->bigdl-nano[pytorch]->bigdl-chronos[all]==2.0.0) (7.1.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.37.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (2022.5.18.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (3.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (5.7.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (0.18.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime->bigdl-nano[pytorch]->bigdl-chronos[all]==2.0.0) (2.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.31.6)
# Collecting opencensus-context>=0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[tune]==1.9.2->bigdl-orca==2.0.0->bigdl-chronos[all]==2.0.0) (1.56.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->bigdl-chronos[all]==2.0.0) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->bigdl-chronos[all]==2.0.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->bigdl-chronos[all]==2.0.0) (3.1.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->bigdl-chronos[all]==2.0.0) (0.5.2)
# Building wheels for collected packages: pyspark, gpustat, future, PyTurboJPEG
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-2.4.6-py2.py3-none-any.whl size=218814407 sha256=d4723a45d054092b3c8f681696089b9fcad24a191475003b742de30399a078c9
#   Stored in directory: /root/.cache/pip/wheels/f1/42/b0/ba397759613f4feb1611021a2503e60e344e546671b2ae04f8
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-1.0.0b1-py3-none-any.whl size=15979 sha256=aadb9387cce382a5a0b14de4e420f0c866c282f596d40c70c599a49f0150127b
#   Stored in directory: /root/.cache/pip/wheels/1a/16/e2/3e2437fba4c4b6a97a97bd96fce5d14e66cff5c4966fb1cc8c
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=74f82e14a1af9bc65a7092e98d0e2a3ae9a92b52783b83f929112f3e10509325
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for PyTurboJPEG (setup.py) ... done
#   Created wheel for PyTurboJPEG: filename=PyTurboJPEG-1.6.6-py3-none-any.whl size=12169 sha256=652ed8f7c61bebd7ddd1d3da8e3ddce227d5e2bb7ec87a833bef0d732935d21c
#   Stored in directory: /root/.cache/pip/wheels/d4/ad/ad/eae0f574bbf7271d34d605ee01338bd4f2c132de91bff0f12f
# Successfully built pyspark gpustat future PyTurboJPEG
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, torch, py4j, fsspec, deprecated, aiohttp, torchmetrics, redis, pyyaml, pyspark, pyDeprecate, opencensus-context, hiredis, future, blessed, torchvision, tensorboardX, ray, PyTurboJPEG, pytorch-lightning, py-spy, pandas, opencv-transforms, opencv-python-headless, opencensus, onnxruntime, onnx, gpustat, conda-pack, colorful, bigdl-tf, bigdl-nano, bigdl-math, bigdl-dllib, aioredis, aiohttp-cors, setproctitle, bigdl-orca, bigdl-chronos
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.12.0+cu113
#     Uninstalling torchvision-0.12.0+cu113:
#       Successfully uninstalled torchvision-0.12.0+cu113
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.9.0 which is incompatible.
# Successfully installed PyTurboJPEG-1.6.6 aiohttp-3.8.1 aiohttp-cors-0.7.0 aioredis-1.3.1 aiosignal-1.2.0 async-timeout-4.0.1 asynctest-0.13.0 bigdl-chronos-2.0.0 bigdl-dllib-2.0.0 bigdl-math-2.0.0 bigdl-nano-2.0.0 bigdl-orca-2.0.0 bigdl-tf-2.0.0 blessed-1.19.1 colorful-0.5.4 conda-pack-0.3.1 deprecated-1.2.13 frozenlist-1.3.0 fsspec-2022.5.0 future-0.18.2 gpustat-1.0.0b1 hiredis-2.0.0 multidict-6.0.2 onnx-1.11.0 onnxruntime-1.11.1 opencensus-0.9.0 opencensus-context-0.1.2 opencv-python-headless-4.6.0.66 opencv-transforms-0.0.6 pandas-1.2.5 py-spy-0.3.12 py4j-0.10.7 pyDeprecate-0.3.1 pyspark-2.4.6 pytorch-lightning-1.4.2 pyyaml-6.0 ray-1.9.2 redis-4.1.4 setproctitle-1.2.3 tensorboardX-2.5.1 torch-1.9.0 torchmetrics-0.9.1 torchvision-0.10.0 yarl-1.7.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics==0.7.3
#   Downloading torchmetrics-0.7.3-py3-none-any.whl (398 kB)
#      |████████████████████████████████| 398 kB 5.1 MB/s
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.7.3) (1.9.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.7.3) (1.21.6)
# Requirement already satisfied: pyDeprecate==0.3.* in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.7.3) (0.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.7.3) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics==0.7.3) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics==0.7.3) (3.0.9)
# Installing collected packages: torchmetrics
#   Attempting uninstall: torchmetrics
#     Found existing installation: torchmetrics 0.9.1
#     Uninstalling torchmetrics-0.9.1:
#       Successfully uninstalled torchmetrics-0.9.1
# Successfully installed torchmetrics-0.7.3
# Found existing installation: torchtext 0.12.0
# Uninstalling torchtext-0.12.0:
#   Successfully uninstalled torchtext-0.12.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pmdarima
#   Downloading pmdarima-1.8.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.1 MB/s
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading statsmodels-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 44.6 MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.2.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.30)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.9)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.5 statsmodels-0.13.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("/content/drive/MyDrive/Courses/Khoá luận tốt nghiệp/Dataset/final_data_6.csv")
# df = pd.read_csv("/content/drive/MyDrive/Khoá luận tốt nghiệp/Dataset/final_data_6.csv")
df['datetime'] = df['datetime'].astype('datetime64')
df

#------------>>> IMPORT NECESARY LIBRARIES AND MODULES
from bigdl.orca import init_orca_context, stop_orca_context
from bigdl.orca import OrcaContext
from bigdl.chronos.data import TSDataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import bigdl.orca.automl.hp as hp
from bigdl.chronos.forecaster.arima_forecaster import ARIMAForecaster
from bigdl.orca.automl.metrics import Evaluator

#------------>>> RECOMMENDED TO SET IT TO TRUE WHEN RUNNING BIGDL-CHRONOS IN JUPYTER NOTEBOOK 
OrcaContext.log_output = True # (this will display terminal's stdout and stderr in the Jupyter notebook).

init_orca_context(cluster_mode="local", cores=4, init_ray_on_spark=True) # run in local mode



#------------>>> LOOP FOR FEATURES

tsdata_train, tsdata_val, tsdata_test = TSDataset.from_pandas(df, dt_col="datetime", id_col="id", target_col="value", with_split=True, val_ratio=0.1, test_ratio=0.1)

# minmax_scaler = MinMaxScaler()

# for tsdata in [tsdata_train, tsdata_val, tsdata_test]:
#   tsdata.scale(minmax_scaler, fit=(tsdata is tsdata_train))

# X_train, y_train = tsdata_train.to_numpy()
# X_val, y_val = tsdata_val.to_numpy()
# X_test, y_test = tsdata_test.to_numpy()
# X_train.shape, y_train.shape, X_test.shape, y_test.shape

train_data = tsdata_train.to_pandas()
validation_data = tsdata_val.to_pandas()
test_data = tsdata_test.to_pandas()

print(train_data.shape[0])
print(validation_data.shape[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/bigdl/chronos/forecaster/__init__.py:36: UserWarning: Please install `tensorflow<2.0.0` to use MTNetForecaster.
#   warnings.warn("Please install `tensorflow<2.0.0` to use MTNetForecaster.")
# /usr/local/lib/python3.7/dist-packages/bigdl/chronos/forecaster/__init__.py:41: UserWarning: Please install `prophet` to use ProphetForecaster.
#   warnings.warn("Please install `prophet` to use ProphetForecaster.")
# Initializing orca context
# Current pyspark location is : /usr/local/lib/python3.7/dist-packages/pyspark/__init__.py
# Start to getOrCreate SparkContext
# pyspark_submit_args is:  --driver-class-path /usr/local/lib/python3.7/dist-packages/bigdl/share/dllib/lib/bigdl-dllib-spark_2.4.6-2.0.0-jar-with-dependencies.jar:/usr/local/lib/python3.7/dist-packages/bigdl/share/orca/lib/bigdl-orca-spark_2.4.6-2.0.0-jar-with-dependencies.jar pyspark-shell
# 2022-06-14 14:12:55 WARN  NativeCodeLoader:62 - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/lib/python3.7/dist-packages/pyspark/jars/spark-unsafe_2.11-2.4.6.jar) to method java.nio.Bits.unaligned()
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2022-06-14 14:12:58,191 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 2022-06-14 14:12:58,196 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 2022-06-14 14:12:58,199 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 2022-06-14 14:12:58,200 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 22-06-14 14:12:58 [Thread-3] INFO  Engine$:121 - Auto detect executor number and executor cores number
# 22-06-14 14:12:58 [Thread-3] INFO  Engine$:123 - Executor number is 1 and executor cores number is 4
# User settings:
#
#    KMP_AFFINITY=granularity=fine,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    OMP_NUM_THREADS=1
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_HAND_THREAD=false
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_FORKJOIN_FRAMES=true
#    KMP_FORKJOIN_FRAMES_MODE=3
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_ITT_PREPARE_DELAY=0
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_MWAIT_HINTS=0
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USER_LEVEL_MWAIT=false
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=true
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEBUG=disabled
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=2147483647
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED=false
#    OMP_NUM_THREADS='1'
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_TOOL=enabled
#    OMP_TOOL_LIBRARIES: value is not defined
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='noverbose,warnings,respect,granularity=fine,compact,1,0'
# 22-06-14 14:12:59 [Thread-3] INFO  ThreadPool$:95 - Set mkl threads to 1 on thread 17
# 2022-06-14 14:12:59 WARN  SparkContext:66 - Using an existing SparkContext; some configuration may not take effect.
# 22-06-14 14:12:59 [Thread-3] INFO  Engine$:446 - Find existing spark context. Checking the spark conf...
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.Sample
# BigDLBasePickler registering: bigdl.dllib.utils.common  Sample
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.EvaluatedResult
# BigDLBasePickler registering: bigdl.dllib.utils.common  EvaluatedResult
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.JTensor
# BigDLBasePickler registering: bigdl.dllib.utils.common  JTensor
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.JActivity
# BigDLBasePickler registering: bigdl.dllib.utils.common  JActivity
# Successfully got a SparkContext
# 2022-06-14 14:13:02,117	INFO services.py:1340 -- View the Ray dashboard at http://172.28.0.2:8265
# {'node_ip_address': '172.28.0.2', 'raylet_ip_address': '172.28.0.2', 'redis_address': '172.28.0.2:6379', 'object_store_address': '/tmp/ray/session_2022-06-14_14-12-59_149265_920/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-06-14_14-12-59_149265_920/sockets/raylet', 'webui_url': '172.28.0.2:8265', 'session_dir': '/tmp/ray/session_2022-06-14_14-12-59_149265_920', 'metrics_export_port': 50539, 'node_id': 'c413a4d1e5306b8576d78d9cd1ad1fc0a68168bf569340616df0061a'}
# 154176
# 19272

# %%
# BUILD MODEL
forecaster = ARIMAForecaster(p=2, q=2, seasonality_mode=True, P=3, Q=1, m=7)
forecaster.fit(train_data['value'].to_numpy(), validation_data['value'].to_numpy())
# Out:
# 2022-06-14 14:14:17,940	WARNING worker.py:1245 -- (ip=172.28.0.2) The agent on node 1f527c611da3 failed to be restarted 5 times. There are 3 possible problems if you see this error.
#   1. The dashboard might not display correct information on this node.
#   2. Metrics on this node won't be reported.
#   3. runtime_env APIs won't work.
# Check out the `dashboard_agent.log` to see the detailed failure messages.
# {'mse': 1945652.6585134156}

# %%
# PREDICT
y_pred = forecaster.predict(horizon=19272, rolling=False)
y_pred
# Out:
# array([  2.9505986 ,  -7.96182294,  19.3190383 , ..., 100.79616698,
#        100.7956747 , 100.79518242])

# %%
# EVALUATE
forecaster.evaluate(test_data['value'].to_numpy(), metrics=['rmse', 'mae', 'mape', 'smape'])
# Out:
# [array(1303.2506963), array(903.35365659), array(inf), array(1.27344988)]

# %%
# EVALUATE with Sklearn metric
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
def s_mape(a, f):
  return 1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f)))
    # return 1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f))*100)

rmse = mean_squared_error(test_data['value'].to_numpy(), y_pred, squared=False)
mae = mean_absolute_error(test_data['value'].to_numpy(), y_pred)
mape = mean_absolute_percentage_error(test_data['value'].to_numpy(), y_pred)
smape = s_mape(test_data['value'].to_numpy(), y_pred)

print("Kết quả dự đoán trên tập test full:")
print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
print('sMAPE:', smape)
# Out:
# Kết quả dự đoán trên tập test full:
# RMSE: 1303.250696302745
# MAE: 903.3536565892498
# MAPE: 8318347074716855.0
# sMAPE: 1.2734498786209487

# %% [markdown]
# ## **Evaluate Table**

# %%
test_data['pred'] = y_pred
test_data
# Out:
#                    id            datetime  value  irain  rain  itemp  temp  \
# 173448  000000001253A 2021-11-25 12:00:00   3110      0   0.0      0   5.4
# 173470  000000001253A 2021-11-25 13:00:00   3151      0   0.0      0   5.8
# 173492  000000001253A 2021-11-25 14:00:00   3067      0   0.0      0   6.1
# 173514  000000001253A 2021-11-25 15:00:00   3491      0   0.0      0   6.0
# 173536  000000001253A 2021-11-25 16:00:00   3594      0   0.0      0   5.5
# ...               ...                 ...    ...    ...   ...    ...   ...
# 192631  000000020223B 2021-12-31 19:00:00    210      0   0.4      0  11.6
# 192653  000000020223B 2021-12-31 20:00:00    139      0   0.3      0  11.6
# 192675  000000020223B 2021-12-31 21:00:00     69      2   0.0      0  11.4
# 192697  000000020223B 2021-12-31 22:00:00     52      2   0.0      0  11.1
# 192719  000000020223B 2021-12-31 23:00:00     43      0   0.0      0  11.0
#
#         iwb  wetb  dewpt  ...  GL3  1283  1258  1256  weekday  weekend  \
# 173448    0   4.0    2.0  ...    0     0     0     0        3        0
# 173470    0   4.3    2.0  ...    0     0     0     0        3        0
# 173492    0   4.3    1.6  ...    0     0     0     0        3        0
# 173514    0   4.3    1.9  ...    0     0     0     0        3        0
# 173536    0   3.9    1.5  ...    0     0     0     0        3        0
# ...     ...   ...    ...  ...  ...   ...   ...   ...      ...      ...
# 192631    0  11.6   11.5  ...    0     0     0     0        4        0
# 192653    0  11.5   11.4  ...    0     0     0     0        4        0
# 192675    0  11.2   11.1  ...    0     0     0     0        4        0
# 192697    0  10.9   10.8  ...    0     0     0     0        4        0
# 192719    0  10.6   10.3  ...    0     0     0     0        4        0
#
#              lat     long  holiday        pred
# 173448  51.87488 -8.44783        0    2.950599
# 173470  51.87488 -8.44783        0   -7.961823
# 173492  51.87488 -8.44783        0   19.319038
# 173514  51.87488 -8.44783        0   44.991762
# 173536  51.87488 -8.44783        0  106.286469
# ...          ...      ...      ...         ...
# 192631  51.88714 -8.56911        0  100.797152
# 192653  51.88714 -8.56911        0  100.796659
# 192675  51.88714 -8.56911        0  100.796167
# 192697  51.88714 -8.56911        0  100.795675
# 192719  51.88714 -8.56911        0  100.795182
#
# [19272 rows x 43 columns]

# %%
list_id = ['000000001253A',
 '000000001253B',
 '000000001255A',
 '000000001255B',
 '000000001256A',
 '000000001256B',
 '000000001258A',
 '000000001258B',
 '000000001271A',
 '000000001271B',
 '000000001283A',
 '000000001283B',
 '000000001401A',
 '000000001401B',
 '000000001403A',
 '000000001403B',
 '000000001404A',
 '000000001404B',
 '000000001405A',
 '000000001405B',
 '000000020223A',
 '000000020223B']
result = pd.DataFrame()
for i in list_id:
  df_filter = test_data[test_data['id'] == i].iloc[50:,:]
  result = pd.concat([result, df_filter])

result.to_csv("/content/drive/MyDrive/Courses/Khoá luận tốt nghiệp/Notebook/Notebook Model/Compare Model/Result_Forecaster_ARIMA.csv", index=False)
result
# Out:
#                    id            datetime  value  irain  rain  itemp  temp  \
# 174548  000000001253A 2021-11-27 14:00:00   3395      0   0.0      0   5.1
# 174570  000000001253A 2021-11-27 15:00:00   3174      0   0.0      0   4.7
# 174592  000000001253A 2021-11-27 16:00:00   3312      0   0.0      0   4.2
# 174614  000000001253A 2021-11-27 17:00:00   2785      0   0.0      0   3.5
# 174636  000000001253A 2021-11-27 18:00:00   2225      3   0.0      0   3.0
# ...               ...                 ...    ...    ...   ...    ...   ...
# 192631  000000020223B 2021-12-31 19:00:00    210      0   0.4      0  11.6
# 192653  000000020223B 2021-12-31 20:00:00    139      0   0.3      0  11.6
# 192675  000000020223B 2021-12-31 21:00:00     69      2   0.0      0  11.4
# 192697  000000020223B 2021-12-31 22:00:00     52      2   0.0      0  11.1
# 192719  000000020223B 2021-12-31 23:00:00     43      0   0.0      0  11.0
#
#         iwb  wetb  dewpt  ...  GL3  1283  1258  1256  weekday  weekend  \
# 174548    0   2.7   -1.5  ...    0     0     0     0        5        1
# 174570    0   2.5   -1.4  ...    0     0     0     0        5        1
# 174592    0   2.3   -1.0  ...    0     0     0     0        5        1
# 174614    0   1.9   -1.0  ...    0     0     0     0        5        1
# 174636    0   1.5   -1.3  ...    0     0     0     0        5        1
# ...     ...   ...    ...  ...  ...   ...   ...   ...      ...      ...
# 192631    0  11.6   11.5  ...    0     0     0     0        4        0
# 192653    0  11.5   11.4  ...    0     0     0     0        4        0
# 192675    0  11.2   11.1  ...    0     0     0     0        4        0
# 192697    0  10.9   10.8  ...    0     0     0     0        4        0
# 192719    0  10.6   10.3  ...    0     0     0     0        4        0
#
#              lat     long  holiday        pred
# 174548  51.87488 -8.44783        0  108.144095
# 174570  51.87488 -8.44783        0  109.009329
# 174592  51.87488 -8.44783        0  109.600376
# 174614  51.87488 -8.44783        0  110.344507
# 174636  51.87488 -8.44783        0  110.615787
# ...          ...      ...      ...         ...
# 192631  51.88714 -8.56911        0  100.797152
# 192653  51.88714 -8.56911        0  100.796659
# 192675  51.88714 -8.56911        0  100.796167
# 192697  51.88714 -8.56911        0  100.795675
# 192719  51.88714 -8.56911        0  100.795182
#
# [18172 rows x 43 columns]

# %%
# EVALUATE with Sklearn metric
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
def s_mape(a, f):
  return 1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f)))
    # return 1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f))*100)

rmse = mean_squared_error(result['value'].to_numpy(), result['pred'].to_numpy(), squared=False)
mae = mean_absolute_error(result['value'].to_numpy(), result['pred'].to_numpy())
mape = mean_absolute_percentage_error(result['value'].to_numpy(), result['pred'].to_numpy())
smape = s_mape(result['value'].to_numpy(), result['pred'].to_numpy())

print("Kết quả dự đoán trên tập test đã cắt 50 dòng mỗi sensor:")
print('RMSE:', rmse)
print('MAE:', mae)
print('MAPE:', mape)
print('sMAPE:', smape)
# Out:
# Kết quả dự đoán trên tập test đã cắt 50 dòng mỗi sensor:
# RMSE: 1292.4882861920614
# MAE: 893.7665651442949
# MAPE: 6179884130826285.0
# sMAPE: 1.2656764292899902
